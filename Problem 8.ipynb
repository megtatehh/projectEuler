# %%
series = ...
strseries= str(series)
counter=0
dictionaryOfCounterToProduct={}
while counter < len(strseries)-12:
    elements=[]
    for x in range(0,13):
        elements.append(int(strseries[counter+x]))
    result=1
    for x in elements:
        result=result*x
    dictionaryOfCounterToProduct[counter] = result
    counter=counter+1

# %%
print('Read the top one')
sorted(dictionaryOfCounterToProduct.items(), key=lambda x: x[1], reverse=True)
# Out:
# Read the top one
# [(197, 23514624000),
#  (196, 14108774400),
#  (498, 8821658160),
#  (499, 7841473920),
#  (195, 6270566400),
#  (501, 5377010688),
#  (500, 4480842240),
#  (497, 3780710640),
#  (719, 3715891200),
#  (720, 3715891200),
#  (88, 2972712960),
#  (496, 2700507600),
#  (715, 2612736000),
#  (90, 2477260800),
#  (503, 2091059712),
#  (698, 2090188800),
#  (829, 2048385024),
#  (43, 2040733440),
#  (89, 1857945600),
#  (830, 1820786688),
#  (502, 1792336896),
#  (91, 1651507200),
#  (714, 1632960000),
#  (41, 1632586752),
#  (42, 1632586752),
#  (495, 1500282000),
#  (538, 1189085184),
#  (832, 1170505728),
#  (697, 1161216000),
#  (717, 1161216000),
#  (287, 1114767360),
#  (713, 1088640000),
#  (40, 1020366720),
#  (358, 987614208),
#  (532, 940584960),
#  (504, 929359872),
#  (696, 928972800),
#  (718, 928972800),
#  (721, 928972800),
#  (831, 910393344),
#  (716, 870912000),
#  (288, 836075520),
#  (155, 812851200),
#  (156, 812851200),
#  (357, 768144384),
# ...
